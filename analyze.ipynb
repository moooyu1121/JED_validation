# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_excel('data/stte_1990a.xlsx')
df
# Out:
#      1990FY           Unnamed: 1  \
# 0       NaN                  NaN
# 1       NaN                  NaN
# 2       NaN                  NaN
# 3       NaN  << Original Unit >>
# 4       NaN                固有単位表
# ..      ...                  ...
# 57      #36                  NaN
# 58      NaN                  NaN
# 59      #37                  NaN
# 60      NaN                  NaN
# 61   1990FY                  NaN
#
#                                            Unnamed: 2                   $  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# ..                                                ...                 ...
# ...
